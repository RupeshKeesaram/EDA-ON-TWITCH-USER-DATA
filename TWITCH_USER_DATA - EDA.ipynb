# %% [markdown]
# # BREIF  DESCRIPTION OF THIS NOTEBOOK
#
# * This notebook mainly consists of the following steps
# > 1. Basic operations for simple understanding of data.
# > 2. EDA for better understanding of data.
# > 3. Outliers detection.
# > 4. Feature selection.
# > 5. Model building and Training.

# %% [markdown]
# ![regex_video1.gif](attachment:regex_video1.gif)
# ## 1. BASIC OPERATIONS

# %%
# import all the necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# reading data from "Twitch_user_data.csv" file

data = pd.read_csv("Downloads/Twitch_user_data.csv")

# %%
# top 20 records of data

data.head(20)
# Out:
#                    Channel  Watch time(Minutes)  Stream time(minutes)  \
# 0                    xQcOW           6196161750                215250
# 1                 summit1g           6091677300                211845
# 2                   Gaules           5644590915                515280
# 3                 ESL_CSGO           3970318140                517740
# 4                     Tfue           3671000070                123660
# 5                Asmongold           3668799075                 82260
# 6                NICKMERCS           3360675195                136275
# 7               Fextralife           3301867485                147885
# 8                loltyler1           2928356940                122490
# 9                  Anomaly           2865429915                 92880
# 10            TimTheTatman           2834436990                108780
# 11                   LIRIK           2832930285                128490
# 12  Riot Games (riotgames)           2674646715                 80820
# 13                  Rubius           2588632635                 58275
# 14               auronplay           2410022550                 40575
# 15          MontanaBlack88           2408460990                 67740
# 16              sodapoppin           2329440420                115305
# 17      풍월량 (hanryang1125)           2186662470                181230
# 18                alanzoka           2055003870                103770
# 19             CohhCarnage           2029212570                175230
#
#     Peak viewers  Average viewers  Followers  Followers gained  Views gained  \
# 0         222720            27716    3246298           1734810      93036735
# 1         310998            25610    5310163           1370184      89705964
# 2         387315            10976    1767635           1023779     102611607
# 3         300575             7714    3944850            703986     106546942
# 4         285644            29602    8938903           2068424      78998587
# 5         263720            42414    1563438            554201      61715781
# 6         115633            24181    4074287           1089824      46084211
# 7          68795            18985     508816            425468     670137548
# 8          89387            22381    3530767            951730      51349926
# 9         125408            12377    2607076           1532689      36350662
# 10        142067            25664    5265659           1244341      50119786
# 11         89170            21739    2666382            199077      50504526
# 12        639375            20960    4487489            497678      56855694
# 13        240096            42948    5751354           3820532      58599449
# 14        170115            53986    3983847           3966525      41514854
# 15        181600            33514    2911316           1101093      37189666
# 16        107833            19659    2786162            236169      39334821
# 17         26999            12201     494445             92205      34405975
# 18         89153            19560    3445134           1325075      46515698
# 19         43615            11343    1264808            124242      38718674
#
#     Partnered  Mature    Language
# 0        True   False     English
# 1        True   False     English
# 2        True    True  Portuguese
# 3        True   False     English
# 4        True   False     English
# 5        True   False     English
# 6        True   False     English
# 7        True   False     English
# 8        True   False     English
# 9        True   False     English
# 10       True    True     English
# 11       True   False     English
# 12       True   False     English
# 13       True   False     Spanish
# 14       True   False     Spanish
# 15       True    True      German
# 16       True    True     English
# 17       True   False      Korean
# 18       True   False  Portuguese
# 19       True   False     English

# %%
# bottom 20 records of data

data.tail(20)
# Out:
#                Channel  Watch time(Minutes)  Stream time(minutes)  \
# 980              Hitch            124224555                132870
# 981            calango            124180125                 70155
# 982        Adin2Huncho            124133550                 64920
# 983        SlotRoom247            124078200                373800
# 984           ALLinPav            124058985                137760
# 985           Surefour            124056555                 53145
# 986      NumotTheNummy            123899265                105930
# 987         aminematue            123826230                 30480
# 988   CallMeCarsonLIVE            123486240                 14340
# 989         ZiggyDLive            123398085                 99075
# 990           KEEMSTAR            123365895                  3465
# 991  크캣66 (crazzyccat)            123279435                192780
# 992         RelaxBeats            123273930                521430
# 993  LAGTVMaximusBlack            123125340                161535
# 994        Destructoid            122628630                103020
# 995          LITkillah            122524635                 13560
# 996   빅헤드 (bighead033)            122523705                153000
# 997     마스카 (newmasca)            122452320                217410
# 998      AndyMilonakis            122311065                104745
# 999               Remx            122192850                 99180
#
#      Peak viewers  Average viewers  Followers  Followers gained  Views gained  \
# 980          3976              875      96343             30813       1942552
# 981          8380             1736     767187            293608       3292645
# 982         14502             1470     199880            162642        956614
# 983         20609              326      69183             69113       1338301
# 984          6221              850      71579             21360       3156265
# 985          7911             2289     331662             46991       2066041
# 986          3359             1118     103069              8045       1530401
# 987         16577             4016     124232            123363       2316908
# 988         61531             8208    1151712            732108       3533199
# 989         18437             1227     173807             15899       4249580
# 990         74195            35333     146035             46367       7139253
# 991          2543              644      35930             24849       1889696
# 992          2830              235     166162             29595       1094850
# 993          7138              725     256353             13251       2310313
# 994         14566             1190      48007              8995      87603521
# 995         21359             9104     601927            562691       2162107
# 996          3940              793     213212             52289       4399897
# 997          6431              567     109068             -4942       3417970
# 998         10543             1153     547446            109111       3926918
# 999         13788             1205     178553             59432       2049420
#
#      Partnered  Mature    Language
# 980       True    True     English
# 981       True   False  Portuguese
# 982       True   False     English
# 983      False    True      German
# 984       True    True     English
# 985       True    True     English
# 986       True   False     English
# 987       True   False      French
# 988       True    True     English
# 989       True   False     English
# 990      False   False     English
# 991       True   False      Korean
# 992       True   False     English
# 993       True    True     English
# 994       True   False     English
# 995       True   False     Spanish
# 996       True   False      Korean
# 997       True   False      Korean
# 998       True   False     English
# 999       True   False      French

# %% [markdown]
# * As the first record index starts from 0 we will be having 999 as the last record index

# %%
# Shape of DataFrame

data.shape
# Out:
# (1000, 11)

# %%
# total number of records in the dataset

print("There are totally {} records in our dataset".format(data.index.stop))
# Out:
# There are totally 1000 records in our dataset

# %%
# all column names

data.columns
# Out:
# Index(['Channel', 'Watch time(Minutes)', 'Stream time(minutes)',
#        'Peak viewers', 'Average viewers', 'Followers', 'Followers gained',
#        'Views gained', 'Partnered', 'Mature', 'Language'],
#       dtype='object')

# %% [markdown]
# ## 2. EDA FOR BETTER UNDERSTANDING OF DATA

# %%
# let's see all the column types before performing any visualization

data.dtypes
# Out:
# Channel                 object
# Watch time(Minutes)      int64
# Stream time(minutes)     int64
# Peak viewers             int64
# Average viewers          int64
# Followers                int64
# Followers gained         int64
# Views gained             int64
# Partnered                 bool
# Mature                    bool
# Language                object
# dtype: object

# %%
# finding any nulll values present in our data

data.isnull().sum()
# Out:
# Channel                 0
# Watch time(Minutes)     0
# Stream time(minutes)    0
# Peak viewers            0
# Average viewers         0
# Followers               0
# Followers gained        0
# Views gained            0
# Partnered               0
# Mature                  0
# Language                0
# dtype: int64

# %% [markdown]
# <h6> There are no missing values to handle</h6>

# %%
# more info about data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Channel               1000 non-null   object
#  1   Watch time(Minutes)   1000 non-null   int64
#  2   Stream time(minutes)  1000 non-null   int64
#  3   Peak viewers          1000 non-null   int64
#  4   Average viewers       1000 non-null   int64
#  5   Followers             1000 non-null   int64
#  6   Followers gained      1000 non-null   int64
#  7   Views gained          1000 non-null   int64
#  8   Partnered             1000 non-null   bool
#  9   Mature                1000 non-null   bool
#  10  Language              1000 non-null   object
# dtypes: bool(2), int64(7), object(2)
# memory usage: 72.4+ KB

# %%
# a breif idea about the data with the help of describe method

data.describe()
# Out:
#        Watch time(Minutes)  Stream time(minutes)   Peak viewers  \
# count         1.000000e+03           1000.000000    1000.000000
# mean          4.184279e+08         120515.160000   37065.051000
# std           5.496355e+08          85376.201364   60314.307686
# min           1.221928e+08           3465.000000     496.000000
# 25%           1.631899e+08          73758.750000    9113.750000
# 50%           2.349908e+08         108240.000000   16676.000000
# 75%           4.337399e+08         141843.750000   37569.750000
# max           6.196162e+09         521445.000000  639375.000000
#
#        Average viewers     Followers  Followers gained  Views gained
# count      1000.000000  1.000000e+03      1.000000e+03  1.000000e+03
# mean       4781.040000  5.700541e+05      2.055185e+05  1.166817e+07
# std        8453.684965  8.044134e+05      3.399137e+05  2.490572e+07
# min         235.000000  3.660000e+03     -1.577200e+04  1.757880e+05
# 25%        1457.750000  1.705462e+05      4.375825e+04  3.880602e+06
# 50%        2425.000000  3.180630e+05      9.835200e+04  6.456324e+06
# 75%        4786.250000  6.243322e+05      2.361308e+05  1.219676e+07
# max      147643.000000  8.938903e+06      3.966525e+06  6.701375e+08

# %%
# finding correlation between features

data.corr()
# Out:
#                       Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# Watch time(Minutes)              1.000000              0.150588      0.582797
# Stream time(minutes)             0.150588              1.000000     -0.119540
# Peak viewers                     0.582797             -0.119540      1.000000
# Average viewers                  0.476165             -0.249248      0.682637
# Followers                        0.620234             -0.091299      0.532529
# Followers gained                 0.514648             -0.158165      0.470415
# Views gained                     0.529862              0.064370      0.298063
# Partnered                        0.038258             -0.007073      0.028112
# Mature                          -0.043197              0.044978     -0.082750
#
#                       Average viewers  Followers  Followers gained  \
# Watch time(Minutes)          0.476165   0.620234          0.514648
# Stream time(minutes)        -0.249248  -0.091299         -0.158165
# Peak viewers                 0.682637   0.532529          0.470415
# Average viewers              1.000000   0.428303          0.420097
# Followers                    0.428303   1.000000          0.715618
# Followers gained             0.420097   0.715618          1.000000
# Views gained                 0.250349   0.276467          0.244297
# Partnered                   -0.008983   0.044418          0.027465
# Mature                      -0.081648  -0.088521         -0.093001
#
#                       Views gained  Partnered    Mature
# Watch time(Minutes)       0.529862   0.038258 -0.043197
# Stream time(minutes)      0.064370  -0.007073  0.044978
# Peak viewers              0.298063   0.028112 -0.082750
# Average viewers           0.250349  -0.008983 -0.081648
# Followers                 0.276467   0.044418 -0.088521
# Followers gained          0.244297   0.027465 -0.093001
# Views gained              1.000000  -0.035313 -0.088119
# Partnered                -0.035313   1.000000  0.000972
# Mature                   -0.088119   0.000972  1.000000

# %% [markdown]
# ### FORMATTING THE CHANNEL NAMES
# * #### If we had observed in detail there are some weird names to some of the channels, so let's fix that now.

# %%
# Sample channel name that's looking differently.

data.iloc[17,0]
# Out:
# '풍월량 (hanryang1125)'

# %% [markdown]
# <h6> So in order to remove that non alphabet letters and to exctarct the exact channel name, I am gonna use regex </h6>

# %%
# exctracting Channel name

import re 

original_chan_names = data["Channel"]
modified_chan_names = []

# regex pattern to exctract Channel names
pattern = "\([a-zA-Z0-9]+\_*[a-zA-Z0-9]*\)"


for i in data["Channel"]:
    if "(" in i:
        val = re.findall(pattern,i)[0]
        modified_chan_names.append(val)
    else:
        modified_chan_names.append(i)
        
# 18th record channel name

modified_chan_names[17]
# Out:
# '(hanryang1125)'

# %%
# removing "(" ")" from extracted movie names

modified_chan_names = [i.strip("()") for i in modified_chan_names]


# Now let's see the 18th record Channel name 
modified_chan_names[17]
# Out:
# 'hanryang1125'

# %%
# replacing the Original channel names with modified Channel names

data["Channel"]=modified_chan_names

# %% [markdown]
# ## Channel names which are top in each categories ( Watch time , followers and etc)

# %%
# finding the channel names which are top in each category

for column in data.columns[1:-3]:
    chan_name = data[data[column]==max(data[column])]["Channel"].values
    print("{} is top in {}".format(chan_name[0],column))
    print()
# Out:
# xQcOW is top in Watch time(Minutes)
#
# RiffTrax is top in Stream time(minutes)
#
# riotgames is top in Peak viewers
#
# dota2ti is top in Average viewers
#
# Tfue is top in Followers
#
# auronplay is top in Followers gained
#
# Fextralife is top in Views gained

# %%
data.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# 3   False     English
# 4   False     English

# %% [markdown]
# # VISUALIZATIONS

# %% [markdown]
# ## A) Simple heatmap showing the correlation between different features

# %%
# setting the figure size
fig = plt.figure(figsize=(10,8))

cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(data.corr(),annot=True,cmap=cmap)
plt.title("Heatmap Showing Correlations")
plt.show()

# %% [markdown]
# * Followers and Watch time(Minutes) are having high positive correlations, i.e When Followers increases then the Watch time(Minutes) also increases.
#
# * Average Viewers and Stream time(Minutes) are having high negative correlation i.e when one feature increases another feature decreases.

# %% [markdown]
# ## B) Pair Plot showing Correlations with the help scatter plot

# %%
# pair plot showing relationship among different features (Bivariate analysis)

samp_data = data[['Watch time(Minutes)', 'Stream time(minutes)',
       'Peak viewers', 'Average viewers', 'Followers', 'Followers gained',
       'Views gained']]


sns.pairplot(samp_data,kind="scatter")
plt.show()

# %% [markdown]
# ## C) Swarm plot Showing relationship between Watch time and Language

# %%
fig = plt.figure(figsize=(10,5))

sns.swarmplot(data["Language"],data["Watch time(Minutes)"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * The English Languae channels are having high watch time compared to other language channels.
# * There are some other languages like Greek, Slovak, Finnish, Swedish and etc are having very less Watch time(Minutes) and also the no of channels using these languages are also less in count.

# %% [markdown]
# ##  D) Scatter plot showing relation between Followers and Watch time(Minutes)

# %%
# simple scatter plot showing relationship between Watch time(Minutes) and Followers

sns.jointplot(data["Followers"],data["Watch time(Minutes)"],kind="scatter",color="r")
plt.show()

# %%
# Counting Matured content channels  and child content channel

Mature_content_chans = data[data["Mature"]==True]["Channel"].values

Child_content_chans = data[data["Mature"]==False]["Channel"].values

print("There are {} Matured  content channels".format(len(Mature_content_chans)))
print("There are {} Non Matured content channels".format(len(Child_content_chans)))
# Out:
# There are 230 Matured  content channels
# There are 770 Non Matured content channels

# %% [markdown]
# ## E) Bar plots showing the count of Mature content channels and Count of partnered Channels

# %%
# Counter plot showing no of Matured content channels 

fig = plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("Count of Mature Content Channels")
sns.countplot(data["Mature"])
plt.plot([],[],color="b",label="False")
plt.plot([],[],color="orange",label="True")
plt.legend()



# Counter plot showing No of Partnered Channels

plt.subplot(1,2,2)
plt.title("Coun of Partnered Channels")
sns.countplot(data["Partnered"])
plt.plot([],[],color="b",label=False)
plt.plot([],[],color="orange",label=True)
plt.legend()
plt.show()

# %% [markdown]
# ## F) Top 5 mostly languages.

# %%
# Top 5 mostly used languages

from collections import Counter

samp_dict = Counter(data["Language"])
top_5_lang = samp_dict.most_common(5)
top_5_lang = dict(top_5_lang)
samp_dict = dict(samp_dict)

fig = plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
plt.pie(top_5_lang.values(),labels=['English', 'Korean', 'Russian', 'Spanish', 'French'],startangle=90)
plt.title("Top 5 Mostly used Languages")
plt.show()

# %%
# bar plot showing count of all languages

fig = plt.figure(figsize=(10,5))
plt.bar(samp_dict.keys(),samp_dict.values(),color="r")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## F) Top 10 channels Details based on their followers

# %%
data.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# 3   False     English
# 4   False     English

# %%
top_10 = sorted(data["Followers"])[-10:]

top_10_chan_names = []
top_10_chan_follows = []
top_10_chan_watch = []
top_10_chan_stream = []
top_10_chan_avg = []


for i,row in data.iterrows():
    if row["Followers"] in top_10:
        top_10_chan_names.append(row["Channel"])
        top_10_chan_follows.append(row["Followers"])
        top_10_chan_watch.append(row["Watch time(Minutes)"])
        top_10_chan_stream.append(row["Stream time(minutes)"])
        top_10_chan_avg.append(row["Average viewers"])

# %% [markdown]
# <h6> Followers of Top 10 channels </h6>

# %%
fig = plt.figure(figsize=(10,5))
plt.bar(top_10_chan_names,top_10_chan_follows,color="#1affa3",width=0.5)
plt.title("Bar plot showing Followers of Top 10 Channels")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h6> Watch time of top 10 channels </h6>

# %%
fig = plt.figure(figsize=(10,5))
plt.bar(top_10_chan_names,top_10_chan_watch,color="#4da6ff",width=0.5)
plt.title("Bar plot showing Watch time(Minutes) of Top 10 Channels")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h6> Stream time of Top 10 Channels </h6>

# %%
fig = plt.figure(figsize=(10,5))
plt.bar(top_10_chan_names,top_10_chan_stream,color="#66ff33",width=0.5)
plt.title("Bar plot showing Stream time(Minutes) of Top 10 Channels")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h6> Average viewers of Top 10 channels

# %%
fig = plt.figure(figsize=(10,5))
plt.bar(top_10_chan_names,top_10_chan_avg,color="#ffff1a",width=0.5)
plt.title("Bar plot showing Average viewers of Top 10 Channels")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 3. OUTLIERS DETECTION
#
# * An outlier is a point or a set of data points which lies away from the rest of the values in the dataset.
# * Problems with outliers
# > 1. Affects the standard deviation of data.
# > 2. Manipulates the overall mean of the data.
# > 3. Converts the data into skewed form.
# > 4. It causes bias in the accuracy estimation of a ML model.
# > 5. Affects the distribution and statistics of dataset.
#
# * Different methods to detect outliers
# > 1. Z-Score
# > 2. Scatter plots
# > 3. IQR (Inter Quartile Range)
#
# In this particular notebook i will be using IQR to find the outliers and will be using boxplots for detecting the outliers visually.

# %%
data.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# 3   False     English
# 4   False     English

# %%
# sample viz showing the outliers present in followers column
sns.boxplot(data["Followers"])

# %% [markdown]
# #### Before removing outliers let's convert all the categorical data into numerical data.
# > Mature, Partnered, Language are the only columns having categorical data.

# %%
# data types before binarization 

data[["Mature","Partnered","Language"]].dtypes
# Out:
# Mature         bool
# Partnered      bool
# Language     object
# dtype: object

# %%
# lambda function for Mature and Partnered
x = lambda a : 1 if a==True else 0

Mature = data["Mature"].apply(x)
Partnered = data["Partnered"].apply(x)

# creating a new column with modified numerical values
data["Mod_Mature"]=Mature
data["Mod_Partnered"]=Partnered

# %%
data["Mod_Mature"].head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Mod_Mature, dtype: int64

# %%
data["Mod_Partnered"].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Mod_Partnered, dtype: int64

# %% [markdown]
# ##### Now let's convert the language column ( Categorical column ) into numerical data column. So for this process i am going to rank the languages based on their Channels count.

# %%
val_dict = data["Language"].value_counts()

# %% [markdown]
# > There are so  many number of Languages for binarization or to assign integer values, so to improve efficieny combine all the languages which is used by less than 20 channels.

# %%
lang_dict = {"English":1,"Korean":2,"Russian":3,"Spanish":4,"French":5,"Portuguese":6,"German":7,"Chinese":8,"Turkish":9,"Other":10}

samp_numeric = []

for i in data["Language"]:
    if val_dict[i]>20:
        samp_numeric.append(samp_dict[i])
    else:
        samp_numeric.append(samp_dict["Other"])

        
# sample top 10 values 
samp_numeric[:10]
# Out:
# [1, 1, 6, 1, 1, 1, 1, 1, 1, 1]

# %%
# adding new column with modified values for language colum
data["Mod_Lang"] = samp_numeric

# %% [markdown]
# ## Outliers removing

# %%
def remove(df,col,outlier):
    q1,q2=np.percentile(col,[25,75])
    iqr = q2-q1
    lb = q1 - 1.5*iqr
    ub = q2 + 1.5*iqr
    for i in range(len(col)):
        if(col[i]>ub or col[i]<lb):
            if df.index[i] not in outlier:
                outlier.append(df.index[i])
                
# creating sample dataframe without categorical data

samp_data= data.drop(["Channel","Mature","Partnered","Language"],axis=1)
samp_data.head()
# Out:
#    Watch time(Minutes)  Stream time(minutes)  Peak viewers  Average viewers  \
# 0           6196161750                215250        222720            27716
# 1           6091677300                211845        310998            25610
# 2           5644590915                515280        387315            10976
# 3           3970318140                517740        300575             7714
# 4           3671000070                123660        285644            29602
#
#    Followers  Followers gained  Views gained  Mod_Mature  Mod_Partnered  \
# 0    3246298           1734810      93036735           0              1
# 1    5310163           1370184      89705964           0              1
# 2    1767635           1023779     102611607           1              1
# 3    3944850            703986     106546942           0              1
# 4    8938903           2068424      78998587           0              1
#
#    Mod_Lang
# 0         1
# 1         1
# 2         6
# 3         1
# 4         1

# %%
# applying the above function to the whole data

outliers = []
for i in samp_data:
    remove(samp_data,samp_data[i],outliers)

# %%
# dropping outliers from the datset
mod_data = data.drop(outliers,axis=0)

# %% [markdown]
# ## 4. FEATURE SELECTION

# %% [markdown]
# * Feature selection is the process of selecting the features which are important for model training and removing the unwanted features.

# %%
new_data = mod_data.drop(["Mature","Channel","Partnered","Language"],axis=1)

# %%
new_data.head(b)
# Out:
#      Watch time(Minutes)  Stream time(minutes)  Peak viewers  Average viewers  \
# 110            812362125                208785         14181             3683
# 112            794621265                108720         24923             7180
# 122            726000045                145755         13080             4922
# 124            721548885                177885         69009             3836
# 127            711864630                152445         17253             4534
#
#      Followers  Followers gained  Views gained  Mod_Mature  Mod_Partnered  \
# 110     185506             29752      20715640           0              1
# 112     755116             68557      15548337           0              1
# 122     346566             37883      12800182           0              1
# 124    1080764            495072      23271722           0              1
# 127     322895             46946      15586820           0              1
#
#      Mod_Lang
# 110         8
# 112         1
# 122         1
# 124        10
# 127         2

# %%
# Followers column will be target feature, so let's separte it now

target_data = new_data["Followers"]

# %% [markdown]
# ## 5. Model Creation and Training

# %%
# importng necessary libraries 

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
# splitting the train and test data

x_train,y_train,x_test,y_test = train_test_split(new_data.drop("Followers",axis=1),target_data,test_size=0.25)

# %%
# sample view of data after splitting

print("Shape of x_train:",x_train.shape)
print("Shape of x_test:",x_test.shape)
print("Shape of y_train:",y_train.shape)
print("Shape of y_test:",y_test.shape)
# Out:
# Shape of x_train: (393, 9)
# Shape of x_test: (393,)
# Shape of y_train: (132, 9)
# Shape of y_test: (132,)

# %%
# Creating an object for linear regression model

linear_mod = LinearRegression()
linear_mod.fit(x_train,x_test)
# Out:
# LinearRegression()

# %%
# predicting values for y_train

y_pred = linear_mod.predict(y_train)

# %%
y_pred
# Out:
# array([564889.5744296 , 590844.29871039, 251897.53685716, 244652.38111099,
#        339577.18960665, 549623.34489885, 182656.89411564, 330770.67253069,
#        311397.38676815, 299333.99477922, 362425.848629  , 455239.10402135,
#        523419.4264579 , 391322.19840904, 254157.74398492, 172968.75487984,
#        308390.46906245, 239424.71719309, 433301.74142478, 219640.53585858,
#        694307.83177038, 385366.98376569, 236579.79372915, 279948.87180616,
#        211947.90872305, 199853.78099706, 471255.43893769, 163460.54162096,
#        346480.24730521, 177897.38607964, 257309.7188546 , 145330.09612014,
#        190078.03417056, 289825.54856116, 379298.54774904, 245922.41407233,
#        710218.09359603, 160791.51700236, 565464.26800005, 406077.77707058,
#        211522.4618083 , 310398.94825812, 334727.57258245, 323511.51996091,
#        486624.18304303, 330177.23174322, 208215.22828981, 450659.30326643,
#        316287.29199683, 306937.58216402, 434481.30045264, 634364.79814364,
#        275433.23313839, 659171.71251188, 231546.50541694, 449229.99906297,
#        239837.05244689, 460472.38957524, 257261.41020422, 180701.53147426,
#        844817.51641257, 371866.61351764, 352897.9410264 , 346112.45600579,
#        205875.17399249, 175221.66252719, 279901.7054101 , 278054.05031264,
#        320506.66657199, 334869.95454985, 310174.24392599, 253027.65686293,
#        267243.02471453, 537413.50236285, 210003.45538794, 270434.40067376,
#        206937.39194151, 451377.02529807, 297627.1635532 , 228842.57612698,
#        279067.31652221, 400381.76806576, 220585.93860513, 567184.10227981,
#        559442.31855466, 265473.33046164, 239120.86580315, 170656.44831643,
#        258957.41719765, 206481.04566696, 310971.47065978, 293248.94133047,
#        211468.67272402, 284960.38661512, 170911.79847985, 387255.09309535,
#        225639.50353256, 181964.93036145, 571300.49727203, 343594.01820795,
#        321199.99434695, 571186.64456197, 231603.41516353, 207689.89412863,
#        297429.01066398, 620315.28251874, 748700.85214025, 165493.21107156,
#        320473.81411461, 601126.39820971, 288473.72367627, 437763.97100188,
#        294409.79898416, 390340.17605817, 192441.72312107, 633591.28551861,
#        422494.39761198, 382962.91860848, 762657.06249488, 204382.91399245,
#        277369.70931711, 372274.08547012, 177056.68328859, 558245.73639239,
#        165565.79591776, 453063.61205243, 158719.2763117 , 222257.10738367,
#        533065.61788004, 283219.74214631, 167451.05977055, 227396.20409839])

# %%
# Model Evalution

# %%
linear_mod.intercept_
# Out:
# 81752.88481146912

# %%
linear_mod.coef_
# Out:
# array([ 1.36642227e-04,  1.30767807e-01, -3.92255147e-01,  1.50842826e+01,
#         1.20347218e+00,  1.03332719e-02,  0.00000000e+00,  0.00000000e+00,
#        -8.83588738e+03])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5153484557359994

# %% [markdown]
# * The main aim of this notebook is EDA we aren't much bothered about the model and efficiency.
# * We can also other metrices like mean absolutre error or mean squared error and etc

# %% [markdown]
# # <CENTER>THANK YOU :)</CENTER>

# %% [markdown]
# ## HAPPY TO SEE ANY SUGGESTIONS TO IMPROVE THIS NOTEBOOK

# %% [markdown]
# # <CENTER> DO SUPPORT BY UPVOTING</CENTER>
